# %% [markdown]
# # Cryptocurrencies Project: Reducing Data Dimensions Using PCA

# %% [markdown]
# In this section we use PCA algorithm from sklearn to reduce the dimensions of the X DataFram down to three principal components.
# And after dimensions reduction, a X_pca dataframe is created tha includes all three priciple components value. This dataframe will be joined with another dataframe in the next

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import hvplot.pandas

# %%
file_path="Resources/X.csv"
X=pd.read_csv(file_path)
X=X.set_index(["Unnamed: 0"])
X.head()
# Out:
#             ProofType  TotalCoinsMined  TotalCoinSupply  Algorithm_536  \
# Unnamed: 0
# 42                  0     4.199995e+01     4.200000e+01              0
# 404                 0     1.055185e+09     5.320000e+08              0
# 1337                0     2.927942e+10     3.141593e+11              0
# BTC                 2     1.792718e+07     2.100000e+07              0
# ETH                 2     1.076842e+08     0.000000e+00              0
#
#             Algorithm_Argon2d  Algorithm_BLAKE256  Algorithm_Blake  \
# Unnamed: 0
# 42                          0                   0                0
# 404                         0                   0                0
# 1337                        0                   0                0
# BTC                         0                   0                0
# ETH                         0                   0                0
#
#             Algorithm_Blake2S  Algorithm_Blake2b  Algorithm_C11  ...  \
# ...

# %%
X_scaled=StandardScaler().fit_transform(X)
print(X_scaled[0])
X_scaled.shape
# Out:
# [-1.40917431 -0.11450078 -0.15072489 -0.04166667 -0.04166667 -0.05897678
#  -0.0934947  -0.04166667 -0.05897678 -0.05897678 -0.04166667 -0.04166667
#  -0.18949048 -0.05897678 -0.0934947  -0.04166667 -0.11081833 -0.0722944
#  -0.04166667 -0.04166667 -0.1518211  -0.04166667 -0.13280318 -0.04166667
#  -0.04166667 -0.0835512  -0.05897678 -0.04166667 -0.04166667 -0.04166667
#  -0.05897678 -0.04166667 -0.0835512  -0.0934947  -0.10250796 -0.04166667
#  -0.1258772  -0.13280318 -0.1518211  -0.04166667 -0.0835512  -0.04166667
#  -0.04166667 -0.0722944  -0.17423301 -0.04166667 -0.04166667 -0.04166667
#  -0.0722944  -0.16888013 -0.30802055 -0.04166667 -0.0934947  -0.0934947
#  -0.05897678  1.39963365 -0.04166667 -0.04166667 -0.04166667 -0.0835512
#  -0.04166667 -0.04166667 -0.04166667 -0.04166667 -0.04166667 -0.05897678
#  -0.04166667 -0.04166667 -0.39536391 -0.04166667 -0.17423301 -0.04166667
#  -0.0835512  -0.0835512  -0.10250796]
# (577, 75)

# %%
pca=PCA(n_components=3)

# %%
X_pca=pca.fit_transform(X_scaled)

# %%
X_pca=pd.DataFrame(data=X_pca,columns=["PC 1", "PC 2", "PC3"])
X_pca.head(10)
# Out:
#        PC 1      PC 2       PC3
# 0 -0.253840 -1.640368  0.996003
# 1 -0.235014 -1.641447  0.995655
# 2  2.773610 -1.805422 -1.275881
# 3 -0.174802  0.875998 -0.785097
# 4 -0.148501  1.799002 -0.326554
# 5 -0.132550 -0.299325  1.460908
# 6 -0.337325 -1.020844 -1.811930
# 7 -0.166135  2.004421 -0.662845
# 8 -0.146717  1.798958 -0.326554
# 9 -0.148170  1.651453  0.296467

# %%
file_path="Resources/X_pca.csv"
X_pca.to_csv(file_path,index=False)
